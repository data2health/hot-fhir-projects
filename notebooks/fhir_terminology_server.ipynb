# %% [markdown]
# # FHIR Terminology Services
# ## REST Server API

# %%
# !pip -q install requests
# !pip -q install jsonasobj

# %%
import sys
from typing import Optional, Union, Dict
import requests
from jsonasobj import JsonObj, loads, as_json
import getpass


class FHIR:
    """ FHIR server wrapper """
    def __init__(self, url: str,
                 user: Optional[str] = None,
                 password: Optional[str] = None,
                 default_format: str = "json",
                 show_urls: bool = False) -> None:

        self.url = url + ('' if url.endswith('/') or url.endswith('#') else '/')
        self.format = default_format
        self._user = user
        self._password = password
        self.metadata = self.get('metadata')
        self.ok = self.metadata is not None
        self.show_urls = show_urls

    @staticmethod
    def logon(url: str, show_urls: bool = False) -> Optional["FHIR"]:
        """ Prompt for a user and password and return a server """
        server = None
        while server is None:
            user = input(f"User id: ")
            if not user:
                return None
            else:
                password = getpass.getpass(f"Password: ")
            server = FHIR(url, user, password, show_urls=show_urls)
        return server

    def __getitem__(self, item: str) -> "FHIRReader":
        """ Convert item to a URI """
        return FHIRReader(item, self)

    def __getattr__(self, item: str) -> Union[object, Optional[JsonObj]]:
        if item.startswith('_'):
            return super().__getattribute__(item)
        else:
            return FHIRReader(item, self)

    def get(self, relurl: Optional[str], params: Optional[Dict[str, str]] = None) -> Optional[JsonObj]:
        url = self.url + relurl
        if self.show_urls:
            print(f"GET {url}")
        resp = requests.get(url, params=params, auth=(self._user, self._password) if self._user else None)
        if resp.ok:
            return loads(resp.text)
        else:
            print(f"{url}: Error: {resp.reason}", file=sys.stderr)
            return None


class FHIRReader:
    def __init__(self, resource: str, server: FHIR) -> None:
        """
        FHIR Resource reader
        :param resource: resource type
        :param server: FHIR server
        """
        self._resource = resource
        self._server = server

    def __getitem__(self, item: str) -> Optional[JsonObj]:
        """ Return <resource>[item] """
        return self._server.get(self._resource + ('/' + item if item != '*' else ''))

    def __getattr__(self, item: str) -> Union[object, Optional[JsonObj]]:
        """ Return <resource>.<item> """
        return super().__getattribute__(item) if item.startswith('_') else self.__getitem__(item)
    
    def lookup(self, **kwargs) -> Optional[JsonObj]:
        return self._server.get(self._resource + '/$lookup', params=kwargs)

# %% [markdown]
# ## Connect to the server

# %%
default_url = 'https://fhir.loinc.org/'
server = FHIR.logon(default_url, show_urls=True)

if server is None:
    sys.exit(1)
# Out:
# User id: hsolbrig
# Password: ········
# GET https://fhir.loinc.org/metadata

# %% [markdown]
# ## Server metadata

# %%
def print_metadata(server: FHIR) -> None:
    m = server.metadata
    print(f"Server {m.implementation.description} at {m.implementation.url} is based on {m.software.name}({m.software.version})")
    print("Resources:")
    supported_resources = []
    for rest in m.rest:
        if rest.mode == 'server':
            for r in rest.resource:
                if hasattr(r, 'interaction'):
                    capabilities = \
                        sorted(list({c.code[0].upper() if c.code in ('create', 'read', 'update', 'delete', 'search') else 'O'
                                    for c in r.interaction}))
                else:
                    capabilities = []
                supported_resources.append(r.type)
                print(f"\t{r.type}: {''.join(capabilities)}")
    print()

    if 'CodeSystem' in supported_resources:
        print("CodeSystems")
        for e in server.CodeSystem['*'].entry:
            print(f"\t{e.resource.name}: {e.resource.title if 'title' in e.resource else 'MISSING Title'} - {e.resource.description if 'description' in e.resource else 'MISSING Description'} ")
        print()

    if 'ValueSet' in supported_resources:
        print("ValueSets")
        for e in server.ValueSet['*'].entry:
            print(f"\t{e.resource.id}: {e.resource.name}")
        print()
print_metadata(server)
# Out:
# Server FHIR REST Server at https://fhir.loinc.org is based on Smile CDR(2019.08.PRE)
# Resources:
# 	CodeSystem: CDORU
# 	ConceptMap: CDORU
# 	OperationDefinition: R
# 	StructureDefinition: OR
# 	Subscription:
# 	ValueSet: CDORU
#
# CodeSystems
# GET https://fhir.loinc.org/CodeSystem
# 	LOINC: LOINC Code System - LOINC is a freely available international standard for tests, measurements, and observations
#
# ValueSets
# GET https://fhir.loinc.org/ValueSet
# 	LL4136-9: Anticoagulant medications
# 	LL4137-7: Preoperative procedures
# 	LL415-1: MERS_TH_15_Eviron-safety event
# 	LL4152-6: CMS IRFPAI_GG0110 Prior Device Use
# 	LL1922-5: NEMSIS_75_EMS condition codes
# 	LL4153-4: CMS IRFPAI_GG Functional Abilies
# 	LL2040-5: Body Surface Area Methods-DICOM
# 	LL4154-2: CMS IRFPAI_GG Functional Goals
# 	LL2110-6: ESRD-open-closed status
# 	LL4155-9: CMS IRFPAI_H0350 Bladder Continence
# 	LL2153-6: VA-36-work/daily activity limitations
# 	LL4752-3: NTDS_I_14_Protective devices
# 	LL2154-4: VA-36-work/social activity limitations
# 	LG37183-7: Albumin/Protein.total|MFr.DF|Urine
# 	valid-hl7-attachment-requests: Valid HL7 Attachment Requests
# 	valid-hl7-attachment-responses: Valid HL7 Attachment Responses
# 	LL1023-2: [PROMIS] Very poor|Poor|Fair|Good|Very good
# 	LL1024-0: [PROMIS] Nev|Alm never|Sometimes|Often|Alm always
# 	LL1031-5: PCR_HK
# 	LL1818-5: NEMSIS_31_adv directive
# 	LL1892-0: ICD-9_ICD-10
# 	LL2155-1: VA-36-body pain
# 	LL2166-8: ESRD-oral vitamin D analog
# 	LL2173-4: ESRD-oral iron type prescribed
# 	LL2197-3: RHEA - pregnancy risk factors
# 	LL2201-3: Smoking Status - HL7 Value Set
# 	LL2202-1: RHEA-birth facility
# 	LL2203-9: RHEA-obstetrical risks
# 	LL2204-7: RHEA-medical history
# 	LL2242-7: C perf toxin genes
# 	LL2257-5: A pleuro bv2
# 	LL2349-0: Reported event previously
# 	LL2358-1: del(13)(q14)
# 	LL2373-0: Cerebrum defects
# 	LL2374-8: Colon defects
# 	LL2375-5: Cranium defects
# 	LL4168-2: [ALSFRS] Turning in bed
# 	LL424-3: MERS_TH_24_Delay-premature factor
# 	LL425-0: MERS_TH_25_Event outcome
# 	LL4256-5: No (0) | Yes (1)
# 	LL4364-7: Private sector|Public sector|Unknown
# 	loinc-rsna-radiology-playbook-core: LOINC/RSNA Radiology Playbook Core
# 	deprecated-loinc-terms: Deprecated Terms
# 	LL436-7: D11_Tooth impaction
# 	LL437-5: D12_Periodontal special finding
# 	LL4636-8: NIDDK_CKD education topics
# 	LL4638-4: DS | D | A | AS | NA
# 	LL465-6: D29_Risk
# 	LL4656-6: Minimal|Moderate|Severe
# 	LL4657-4: Intoxication cause

# %% [markdown]
# ## Look up concept codes

# %%
code = None
while code != '':
    code=input("Enter concept code: ")
    if code:
        loinc_code = server.CodeSystem.lookup(system="http://loinc.org", code=code)
        if loinc_code:
            display = ''.join(p.valueString for p in loinc_code.parameter if p.name == "display")
            print(f"{code}: {display}")
        else:
            print(f"Code: {code} not found")
# Out:
# Enter concept code: 4548-4
# GET https://fhir.loinc.org/CodeSystem/$lookup
# 4548-4: Hemoglobin A1c/Hemoglobin.total in Blood
# Enter concept code: 217042-1
# https://fhir.loinc.org/CodeSystem/$lookup: Error: Not Found
# GET https://fhir.loinc.org/CodeSystem/$lookup
# Code: 217042-1 not found
# Enter concept code: 27042-1
# GET https://fhir.loinc.org/CodeSystem/$lookup
# 27042-1: Methohexital [Mass/volume] in Serum or Plasma
# Enter concept code:

# %% [markdown]
# # Switch to a different server

# %%
server = FHIR("https://r4.ontoserver.csiro.au/fhir", show_urls=True)
print_metadata(server)
# Out:
# GET https://r4.ontoserver.csiro.au/fhir/metadata
# Server Ontoserver, The Australian e-Health Research Centre, CSIRO at https://r4.ontoserver.csiro.au/fhir is based on Ontoserver®(6.0.0-SNAPSHOT)
# Resources:
# 	Account:
# 	ActivityDefinition:
# 	AdverseEvent:
# 	AllergyIntolerance:
# 	Appointment:
# 	AppointmentResponse:
# 	AuditEvent: C
# 	Basic:
# 	BiologicallyDerivedProduct:
# 	BodyStructure:
# 	Bundle: CDORU
# 	CapabilityStatement:
# 	CarePlan:
# 	CareTeam:
# 	CatalogEntry:
# 	ChargeItem:
# 	ChargeItemDefinition:
# 	Claim:
# 	ClaimResponse:
# 	ClinicalImpression:
# 	CodeSystem: CDORU
# 	Communication:
# 	CommunicationRequest:
# 	CompartmentDefinition:
# 	Composition:
# 	ConceptMap: CDORU
# 	Condition:
# 	Consent:
# 	Contract:
# 	Coverage:
# 	CoverageEligibilityRequest:
# 	CoverageEligibilityResponse:
# 	DetectedIssue:
# 	Device:
# 	DeviceDefinition:
# 	DeviceMetric:
# 	DeviceRequest:
# 	DeviceUseStatement:
# 	DiagnosticReport:
# 	DocumentManifest:
# 	DocumentReference:
# 	Encounter:
# 	Endpoint:
# 	EnrollmentRequest:
# 	EnrollmentResponse:
# 	EpisodeOfCare:
# 	EventDefinition:
# 	ExampleScenario:
# 	ExplanationOfBenefit:
# 	FamilyMemberHistory:
# 	Flag:
# 	Goal:
# 	GraphDefinition:
# 	Group:
# 	GuidanceResponse:
# 	HealthcareService:
# 	ImagingStudy:
# 	Immunization:
# 	ImmunizationEvaluation:
# 	ImmunizationRecommendation:
# 	ImplementationGuide:
# 	InsurancePlan:
# 	Invoice:
# 	ItemInstance:
# 	Library:
# 	Linkage:
# 	List:
# 	Location:
# 	Measure:
# 	MeasureReport:
# 	Media:
# 	Medication:
# 	MedicationAdministration:
# 	MedicationDispense:
# 	MedicationKnowledge:
# 	MedicationRequest:
# 	MedicationStatement:
# 	MedicinalProduct:
# 	MedicinalProductAuthorization:
# 	MedicinalProductClinicals:
# 	MedicinalProductContraindication:
# 	MedicinalProductDeviceSpec:
# 	MedicinalProductIndication:
# 	MedicinalProductIngredient:
# 	MedicinalProductInteraction:
# 	MedicinalProductManufactured:
# 	MedicinalProductPackaged:
# 	MedicinalProductPharmaceutical:
# 	MedicinalProductUndesirableEffect:
# 	MessageDefinition:
# 	MessageHeader:
# 	NamingSystem:
# 	NutritionOrder:
# 	Observation:
# 	ObservationDefinition:
# 	OperationDefinition:
# 	OperationOutcome:
# 	Organization:
# 	OrganizationAffiliation:
# 	Patient:
# 	PaymentNotice:
# 	PaymentReconciliation:
# 	Person:
# 	PlanDefinition:
# 	Practitioner:
# 	PractitionerRole:
# 	Procedure:
# 	ProcessRequest:
# 	ProcessResponse:
# 	Provenance:
# 	Questionnaire:
# 	QuestionnaireResponse:
# 	RelatedPerson:
# 	RequestGroup:
# 	ResearchStudy:
# 	ResearchSubject:
# 	RiskAssessment:
# 	Schedule:
# 	SearchParameter:
# 	Sequence:
# 	ServiceRequest:
# 	Slot:
# 	Specimen:
# 	SpecimenDefinition:
# 	StructureDefinition: CDORU
# 	StructureMap:
# 	Subscription:
# 	Substance:
# 	SubstancePolymer:
# 	SubstanceReferenceInformation:
# 	SubstanceSpecification:
# 	SupplyDelivery:
# 	SupplyRequest:
# 	Task:
# 	TerminologyCapabilities:
# 	TestReport:
# 	TestScript:
# 	UserSession:
# 	ValueSet: CDORU
# 	VerificationResult:
# 	VisionPrescription:
#
# CodeSystems
# GET https://r4.ontoserver.csiro.au/fhir/CodeSystem
# 	medicationRequest Course of Therapy Codes: Medication request  course of  therapy  codes - MedicationRequest Course of Therapy Codes
# 	FHIRVersion: FHIRVersion - All published FHIR Versions.
# 	v2.0167: v2 SUBSTITUTION STATUS - FHIR Value set/code system definition for HL7 v2 table 0167 ( SUBSTITUTION STATUS)
# 	ContractResourcePublicationStatusCodes: Contract Resource Publication Status codes - This value set contract specific codes for status.
# 	EvidenceVariantState: EvidenceVariantState - Used for results by exposure in variant states such as low-risk, medium-risk and high-risk states.
# 	v3.EntityCode: v3 Code System EntityCode -   OpenIssue:
# Missing description.
# 	SubscriptionTag: SubscriptionTag - Tags to put on a resource after subscriptions have been sent.
# 	Medication Status Codes: Medication  status  codes - Medication Status Codes
# 	MediaType: Media Type - Codes for high level media categories.
# 	FlagCategory: Flag Category - Example list of general categories for flagged issues. (Not complete or necessarily appropriate.)
# 	ContactEntityType: Contact entity type - This example value set defines a set of codes that can be used to indicate the purpose for which you would contact a contact party.
# 	v2.0210: v2 Relational Conjunction - FHIR Value set/code system definition for HL7 v2 table 0210 ( Relational Conjunction)
# 	v3.ObservationMethod: v3 Code System ObservationMethod -  A code that provides additional detail about the means or technique used to ascertain the observation.  Examples:
# Blood pressure measurement method: arterial puncture vs. sphygmomanometer (Riva-Rocci), sitting vs. supine position, etc.  OpenIssue:
# Description copied from Concept Domain of same name.  Must be verified.  Note that the Domain has a full discussion about use of the attribute and constraining that is not appropriate for the code system description.  Needs to be improved.
# 	FHIR Restful Interactions: MISSING Title - The set of interactions defined by the RESTful part of the FHIR specification.
# 	v2.0355: v2 Primary key value type - FHIR Value set/code system definition for HL7 v2 table 0355 ( Primary key value type)
# 	v2.0121: v2 RESPONSE FLAG - FHIR Value set/code system definition for HL7 v2 table 0121 ( RESPONSE FLAG)
# 	v2.0755: v2 Status Weight At Birth - FHIR Value set/code system definition for HL7 v2 table 0755 ( Status Weight At Birth)
# 	AllergyIntoleranceVerificationStatusCodes: AllergyIntolerance Verification Status Codes - Preferred value set for AllergyIntolerance Verification Status.
# 	v2.0904: v2 Security Check Scheme - FHIR Value set/code system definition for HL7 v2 table 0904 ( Security Check Scheme)
# 	v2.0682: v2 Device Status - FHIR Value set/code system definition for HL7 v2 table 0682 ( Device Status)
# 	v2.0100: v2 WHEN TO CHARGE - FHIR Value set/code system definition for HL7 v2 table 0100 ( WHEN TO CHARGE)
# 	v2.0350: v2 Occurrence code - FHIR Value set/code system definition for HL7 v2 table 0350 ( Occurrence code)
# 	Australian States and Territories: MISSING Title - The Australian States and Territories code system defines concepts that represent the Australian states and territories.
# 	v2.0223: v2 Living Dependency - FHIR Value set/code system definition for HL7 v2 table 0223 ( Living Dependency)
# 	AdverseEventSeriousness: AdverseEventSeriousness - Overall seriousness of this event for the patient.
# 	v2.0326: v2 Visit Indicator - FHIR Value set/code system definition for HL7 v2 table 0326 ( Visit Indicator)
# 	v2.0280: v2 Referral Priority - FHIR Value set/code system definition for HL7 v2 table 0280 ( Referral Priority)
# 	ConstraintSeverity: ConstraintSeverity - SHALL applications comply with this constraint?
# 	ContractResourceExpirationTypeCodes: Contract Resource Expiration Type codes - This value set contract specific codes for status.
# 	EventCapabilityMode: EventCapabilityMode - The mode of a message capability statement.
# 	v3.EntityClass: v3 Code System EntityClass -  Classifies the Entity class and all of its subclasses.  The terminology is hierarchical.  At the top is this  HL7-defined domain of high-level categories (such as represented by the Entity subclasses). Each of these terms must be harmonized and is specializable. The value sets beneath are drawn from multiple, frequently external, domains that reflect much more fine-grained typing.
# 	v2.0048: v2 WHAT SUBJECT FILTER - FHIR Value set/code system definition for HL7 v2 table 0048 ( WHAT SUBJECT FILTER)
# 	v2.0570: v2 Payment Method Code - FHIR Value set/code system definition for HL7 v2 table 0570 ( Payment Method Code)
# 	EventTiming: EventTiming - Real world event relating to the schedule.
# 	TemplateStatusCodeLifeCycle: TemplateStatusCode LifeCycle - Life cycle of the Status Code of a Template Design (Version)
# 	AllergyIntoleranceCategory: AllergyIntoleranceCategory - Category of an identified substance associated with allergies or intolerances.
# 	Australian Indigenous Status: MISSING Title - The Australian Indigenous Status code system defines concepts to support the representation of a person's Indigenous status. That is, whether a person identifies as being of Aboriginal or Torres Strait Islander origin, as represented by a code. The concepts defined in this code system are equivalent to those defined in the METeOR value domains for Person Indigenous status code N for http://meteor.aihw.gov.au/content/index.phtml/itemId/602545, http://meteor.aihw.gov.au/content/index.phtml/itemId/270885, and http://meteor.aihw.gov.au/content/index.phtml/itemId/291036.
# 	concurrent-supply-grounds: Concurrent Supply Grounds - The Concurrent Supply Grounds code system defines concepts for the grounds that authorise a subsidy for the concurrent supply of an item specified in a prescription and all of its repeats.
# 	SubscriberRelationshipCodes: SubscriberPolicyholder Relationship Codes - This value set includes codes for the relationship between the Subscriber and the Beneficiary (insured/covered party/patient).
# 	v3.CompressionAlgorithm: v3 Code System CompressionAlgorithm - **** MISSING DEFINITIONS ****
# 	SupplyItemType: Supply Item Type - This value sets refers to a specific supply item.
# 	SupplyDeliveryStatus: SupplyDeliveryStatus - Status of the supply delivery.
# 	v2.0409: v2 Application change type - FHIR Value set/code system definition for HL7 v2 table 0409 ( Application change type)
# 	v2.0561: v2 Product/Services Clarification Codes - FHIR Value set/code system definition for HL7 v2 table 0561 ( Product/Services Clarification Codes)
# 	v2.0404: v2 Language proficiency - FHIR Value set/code system definition for HL7 v2 table 0404 ( Language proficiency)
# 	v2.0433: v2 Precaution code - FHIR Value set/code system definition for HL7 v2 table 0433 ( Precaution code)
# 	v2.0356: v2 Alternate character set handling scheme - FHIR Value set/code system definition for HL7 v2 table 0356 ( Alternate character set handling scheme)
# 	v2.0331: v2 Facility Type - FHIR Value set/code system definition for HL7 v2 table 0331 ( Facility Type)
# 	v3.TimingEvent: v3 Code System TimingEvent - **** MISSING DEFINITIONS ****
# 	v3.SpecimenType: v3 Code System SpecimenType - **** MISSING DEFINITIONS ****
# 	AuditEventEntityRole: AuditEventEntityRole - Code representing the role the entity played in the audit event.
# 	ExampleProviderQualificationCodes: Example Provider Qualification Codes - This value set includes sample Provider Qualification codes.
# 	ObservationCategoryCodes: Observation Category Codes - Codes to denote a guideline or policy statement.when a genetic test result is being shared as a secondary finding.
# 	v2.0555: v2 Invoice Type - FHIR Value set/code system definition for HL7 v2 table 0555 ( Invoice Type)
# 	v3.HL7UpdateMode: v3 Code System HL7UpdateMode -  The possible modes of updating that occur when an attribute is received by a system that already contains values for that attribute.
# 	v3.SetOperator: v3 Code System SetOperator - **** MISSING DEFINITIONS ****
# 	v2.0085: v2 OBSERVATION RESULT STATUS - FHIR Value set/code system definition for HL7 v2 table 0085 ( OBSERVATION RESULT STATUS)
# 	AlternativeCodeKind: AlternativeCodeKind - Indicates the type of use for which the code is defined.
# 	v2.0558: v2 Payee Relationship to Invoice - FHIR Value set/code system definition for HL7 v2 table 0558 ( Payee Relationship to Invoice)
# 	v2.0483: v2 Authorization Mode - FHIR Value set/code system definition for HL7 v2 table 0483 ( Authorization Mode)
# 	ImmunizationFundingSource: Immunization Funding Source - The value set to instantiate this attribute should be drawn from a terminologically robust code system that consists of or contains concepts to support describing the source of the vaccine administered. This value set is provided as a suggestive example.
# 	v2.0389: v2 Analyte repeat status - FHIR Value set/code system definition for HL7 v2 table 0389 ( Analyte repeat status)
# 	ListEmptyReasons: List Empty Reasons - General reasons for a list to be empty. Reasons are either related to a summary list (i.e. problem or medication list) or to a workflow related list (i.e. consultation list).
# 	MedicationKnowledge Status Codes: Medication knowledge  status  codes - MedicationKnowledge Status Codes
# 	HandlingConditionSet: HandlingConditionSet - Set of handling instructions prior testing of the specimen.
# 	v2.0371: v2 Additive - FHIR Value set/code system definition for HL7 v2 table 0371 ( Additive)
# 	GoalAchievementStatus: Goal achievement status - Describes the progression, or lack thereof, towards the goal against the target.
# 	CatalogType: CatalogType - The type of catalog.
# 	v2.0430: v2 Mode of arrival code - FHIR Value set/code system definition for HL7 v2 table 0430 ( Mode of arrival code)
# 	v2.0445: v2 Identity Reliability Code - FHIR Value set/code system definition for HL7 v2 table 0445 ( Identity Reliability Code)
# 	v2.0364: v2 Comment type - FHIR Value set/code system definition for HL7 v2 table 0364 ( Comment type)
# 	v2.0193: v2 Amount Class - FHIR Value set/code system definition for HL7 v2 table 0193 ( Amount Class)
# 	RejectionCriterion: RejectionCriterion - Criterion for rejection of the specimen by laboratory.
# 	v3.QueryParameterValue: v3 Code System QueryParameterValue -  The domain of coded values used as parameters within QueryByParameter queries.
# 	DefinitionTopic: DefinitionTopic - High-level categorization of the definition, used for searching, sorting, and filtering.
# 	v2.0231: v2 Student Status - FHIR Value set/code system definition for HL7 v2 table 0231 ( Student Status)
# 	FMConditionCodes: FM Condition Codes - This value set includes sample Conditions codes.
# 	v2.0069: v2 Hospital service - FHIR Value set/code system definition for HL7 v2 table 0069 ( Hospital service)
# 	v2.0321: v2 Dispense Method - FHIR Value set/code system definition for HL7 v2 table 0321 ( Dispense Method)
# 	v2.0431: v2 Recreational drug use code - FHIR Value set/code system definition for HL7 v2 table 0431 ( Recreational drug use code)
# 	Date Accuracy Indicator: MISSING Title - The Date Accuracy Indicator code system defines concepts that indicate the accuracy of components of a reported date. The concepts defined in this code system are equivalent to those defined in the METeOR value domains for Date—accuracy indicator, code AAA (http://meteor.aihw.gov.au/content/index.phtml/itemId/294429).
# 	v3.TableCellVerticalAlign: v3 Code System TableCellVerticalAlign -  These values are defined within the XHTML 4.0 Table Model
# 	v2.0895: v2 Present On Admission (POA) Indicator - FHIR Value set/code system definition for HL7 v2 table 0895 ( Present On Admission (POA) Indicator)
# 	v2.0268: v2 Override - FHIR Value set/code system definition for HL7 v2 table 0268 ( Override)
# 	FinancialResourceStatusCodes: Financial Resource Status Codes - This value set includes Status codes.
# 	ContractTermTypeCodes: Contract Term Type Codes - This value set includes sample Contract Term Type codes.
# 	AddressType: AddressType - The type of an address (physical / postal).
# 	AdmitSource: Admit source - This value set defines a set of codes that can be used to indicate from where the patient came in.
# 	v2.0211: v2 Alternate Character Sets - FHIR Value set/code system definition for HL7 v2 table 0211 ( Alternate Character Sets)
# 	v2.0108: v2 QUERY RESULTS LEVEL - FHIR Value set/code system definition for HL7 v2 table 0108 ( QUERY RESULTS LEVEL)
# 	v2.0921: v2 Certification Type Code - FHIR Value set/code system definition for HL7 v2 table 0921 ( Certification Type Code)
# 	AssertionDirectionType: AssertionDirectionType - The type of direction to use for assertion.
# 	v2.0204: v2 Organizational Name Type - FHIR Value set/code system definition for HL7 v2 table 0204 ( Organizational Name Type)
# 	AggregationMode: AggregationMode - How resource references can be aggregated.
# 	v2.0657: v2 Device Type - FHIR Value set/code system definition for HL7 v2 table 0657 ( Device Type)
# 	v2.0185: v2 Preferred Method Of Contrct - FHIR Value set/code system definition for HL7 v2 table 0185 ( Preferred Method Of Contrct)
# 	v3.ContextControl: v3 Code System ContextControl -  A code that specifies how an ActRelationship or Participation contributes to the context of an Act, and whether it may be propagated to descendent Acts whose association allows such propagation (see also attributes Participation.contextControlCode, ActRelationship.contextControlCode, ActRelationship.contextConductionInd).
# 	ActionCardinalityBehavior: ActionCardinalityBehavior - Defines behavior for an action or a group for how many times that item may be repeated.
# 	v2.0323: v2 Action Code - FHIR Value set/code system definition for HL7 v2 table 0323 ( Action Code)
# 	MedicationDispense Category Codes: Medication dispense  category  codes - MedicationDispense Category Codes
# 	v2.0228: v2 Diagnosis Classification - FHIR Value set/code system definition for HL7 v2 table 0228 ( Diagnosis Classification)
# 	NCTIS Data Components: MISSING Title - The National Clinical Terminology and Information Service (NCTIS) Data Components code system defines concepts that identify a data component. The codes can be used to indicate and identify a type of document, a section of a document, or an element.
# 	EpisodeOfCareStatus: EpisodeOfCareStatus - The status of the episode of care.
# 	MedicationAdministration Performer Function Codes: Medication administration  performer  function  codes - MedicationAdministration Performer Function Codes
# 	v2.0480: v2 Pharmacy Order Types - FHIR Value set/code system definition for HL7 v2 table 0480 ( Pharmacy Order Types)
# 	v2.0562: v2 Processing Consideration Codes - FHIR Value set/code system definition for HL7 v2 table 0562 ( Processing Consideration Codes)
# 	v2.0187: v2 Provider billing - FHIR Value set/code system definition for HL7 v2 table 0187 ( Provider billing)
# 	v2.0547: v2 Jurisdictional Breadth - FHIR Value set/code system definition for HL7 v2 table 0547 ( Jurisdictional Breadth)
# 	v2.0436: v2 Sensitivity to Causative Agent code - FHIR Value set/code system definition for HL7 v2 table 0436 ( Sensitivity to Causative Agent code)
# 	ContractResourceScopeCodes: Contract Resource Scope codes - This value set contract specific codes for security classification.
# 	v2.0156: v2 DATE/TIME QUALIFIER - FHIR Value set/code system definition for HL7 v2 table 0156 ( DATE/TIME QUALIFIER)
# 	v3.GenderStatus: v3 Code System GenderStatus - **** MISSING DEFINITIONS ****
# 	GuidanceResponseStatus: GuidanceResponseStatus - The status of a guidance response.
# 	nctis-data-components: NCTIS Data Components - The National Clinical Terminology and Information Service (NCTIS) Data Components code system defines concepts that identify a data component. The codes can be used to indicate and identify a type of document, a section of a document, or an element.
# 	NetworkTypeCodes: Network Type Codes - This value set includes a smattering of Network type codes.
# 	Australian Immunisation Register Vaccine: MISSING Title - The Australian Immunisation Register Vaccine code system defines the vaccine codes available for recording of vaccine administration on the Australian Immunisation Register, and may be used for online claiming and reimbursement for vaccine administration through Medicare.
# 	SubscriptionStatus: SubscriptionStatus - The status of a subscription.
# 	ExamplePharmacyServiceCodes: Example Pharmacy Service Codes - This value set includes a smattering of Pharmacy Service codes.
# 	SupplyRequestReason: SupplyRequestReason - The reason why the supply item was requested.
# 	v3.LocalMarkupIgnore: v3 Code System LocalMarkupIgnore -  Tells a receiver to ignore just the local markup tags (local_markup, local_header, local_attr) when value="markup", or to ignore the local markup tags and all contained content when value="all"
# 	v2.0496: v2 Consent Type - FHIR Value set/code system definition for HL7 v2 table 0496 ( Consent Type)
# 	ConsentPolicyRuleCodes: Consent PolicyRule Codes - This value set includes sample Regulatory consent policy types from the US and other regions.
# 	v2.0145: v2 Room Type - FHIR Value set/code system definition for HL7 v2 table 0145 ( Room Type)
# 	ConsentDataMeaning: ConsentDataMeaning - How a resource reference is interpreted when testing consent restrictions.
# 	v2.0538: v2 Institution Relationship Type - FHIR Value set/code system definition for HL7 v2 table 0538 ( Institution Relationship Type)
# 	v2.0933: v2 Intended Procedure Type - FHIR Value set/code system definition for HL7 v2 table 0933 ( Intended Procedure Type)
# 	LOINC v2.64: MISSING Title - LOINC is a common language (set of identifiers, names, and codes) for clinical and laboratory observations.
# 	v2.0043: v2 Condition code - FHIR Value set/code system definition for HL7 v2 table 0043 ( Condition code)
# 	v2.0484: v2 Dispense Type - FHIR Value set/code system definition for HL7 v2 table 0484 ( Dispense Type)
# 	ContractResourceDefinitionSubtypeCodes: Contract Resource Definition Subtype codes - This value set contract specific codes for status.
# 	GoalLifecycleStatus: GoalLifecycleStatus - Codes that reflect the current state of a goal and whether the goal is still being targeted.
# 	ExampleUseCodesForList: Example Use Codes for List - Example use codes for the List resource - typical kinds of use.
# 	CoverageEligibilityResponseAuthSupportCodes: CoverageEligibilityResponse Auth Support Codes - This value set includes CoverageEligibilityResponse Auth Support codes.
# 	EnteralFormulaAdditiveTypeCode: Enteral Formula Additive Type Code - EnteralFormulaAdditiveType: Codes for the type of modular component such as protein, carbohydrate or fiber to be provided in addition to or mixed with the base formula. This value set is provided as a suggestive example.
# 	v2.0527: v2 Calendar alignment - FHIR Value set/code system definition for HL7 v2 table 0527 ( Calendar alignment)
# 	ConsentCategoryCodes: Consent Category Codes - This value set includes sample Consent Directive Type codes, including several consent directive related LOINC codes; HL7 VALUE SET: ActConsentType(2.16.840.1.113883.1.11.19897); examples of US realm consent directive legal descriptions and references to online and/or downloadable forms such as the SSA-827 Authorization to Disclose Information to the Social Security Administration; and other anticipated consent directives related to participation in a clinical trial, medical procedures, reproductive procedures; health care directive (Living Will); advance directive, do not resuscitate (DNR); Physician Orders for Life-Sustaining Treatment (POLST)
# 	v2.0571: v2 Invoice Processing Results Status - FHIR Value set/code system definition for HL7 v2 table 0571 ( Invoice Processing Results Status)
# 	AdverseEventActuality: AdverseEventActuality - Overall nature of the adverse event, e.g. real or potential.
# 	v2.0491: v2 Specimen Quality - FHIR Value set/code system definition for HL7 v2 table 0491 ( Specimen Quality)
# 	StructureDefinitionKind: StructureDefinitionKind - Defines the type of structure that a definition is describing.
# 	MedicationAdministration Category Codes: Medication administration  category  codes - MedicationAdministration Category Codes
# 	push-type-available: Push-type-available - Type of alerts/updates the primary source can send
# 	v2.0384: v2 Substance type - FHIR Value set/code system definition for HL7 v2 table 0384 ( Substance type)
# 	v2.0418: v2 Procedure priority - FHIR Value set/code system definition for HL7 v2 table 0418 ( Procedure priority)
# 	v2.0140: v2 Military service - FHIR Value set/code system definition for HL7 v2 table 0140 ( Military service)
# 	IssueSeverity: IssueSeverity - How the issue affects the success of the action.
# 	ContractContentDerivationCodes: Contract Content Derivation Codes - This is an example set of Content Derivative type codes, which represent the minimal content derived from the basal information source at a specific stage in its lifecycle, which is sufficient to manage that source information, for example, in a repository, registry, processes and workflows, for making access control decisions, and providing query responses.
# 	v3.EncounterAdmissionSource: v3 Code System EncounterAdmissionSource - **** MISSING DEFINITIONS ****
# 	GuideParameterCode: GuideParameterCode - Code of parameter that is input to the guide.
# 	ExtensionContextType: ExtensionContextType - How an extension context is interpreted.
# 	v2.0065: v2 ACTION CODE - FHIR Value set/code system definition for HL7 v2 table 0065 ( ACTION CODE)
# 	Australian jurisdictions: MISSING Title - MISSING Description
# 	v2.0202: v2 Telecommunication Equipment Type - FHIR Value set/code system definition for HL7 v2 table 0202 ( Telecommunication Equipment Type)
# 	v2.0173: v2 COORDINATION OF BENEFITS - FHIR Value set/code system definition for HL7 v2 table 0173 ( COORDINATION OF BENEFITS)
# 	DataAbsentReason: DataAbsentReason - Used to specify why the normally expected content of the data element is missing.
# 	v2.0272: v2 Document Confidentiality Status - FHIR Value set/code system definition for HL7 v2 table 0272 ( Document Confidentiality Status)
# 	v2.0027: v2 PRIORITY (COMPONENT 6 QTY/TIMING[735]) - FHIR Value set/code system definition for HL7 v2 table 0027 ( PRIORITY (COMPONENT 6 QTY/TIMING[735]))
# 	SupplyRequestStatus: SupplyRequestStatus - Status of the supply request.
# 	QuestionnaireItemOperator: QuestionnaireItemOperator - The criteria by which a question is enabled.
# 	ContractSubtypeCodes: Contract Subtype Codes - This value set includes sample Contract Subtype codes.
# 	RelatedArtifactType: RelatedArtifactType - The type of relationship to the related artifact.
# 	StatisticsCode: StatisticsCode - The statistical operation parameter -"statistic" codes.
# 	SignatureTypeCodes: Signature Type Codes - The Digital Signature Purposes, an indication of the reason an entity signs a document. This is included in the signed information and can be used when determining accountability for various actions concerning the document. Examples include: author, transcriptionist/recorder, and witness.
# 	v2.0141: v2 Military rank/grade - FHIR Value set/code system definition for HL7 v2 table 0141 ( Military rank/grade)
# 	RestfulCapabilityMode: RestfulCapabilityMode - The mode of a RESTful capability statement.
# 	v3.ExposureMode: v3 Code System ExposureMode -  Code for the mechanism by which the exposure agent was exchanged or potentially exchanged by the participants involved in the exposure.
# 	v3.EncounterSpecialCourtesy: v3 Code System EncounterSpecialCourtesy - **** MISSING DEFINITIONS ****
# 	MaxOccurs: MaxOccurs - Flags an element as having unlimited repetitions.
# 	ConditionalReadStatus: ConditionalReadStatus - A code that indicates how the server supports conditional read.
# 	TestScriptProfileOriginType: Test script profile origin type - This value set defines a set of codes that are used to indicate the profile type of a test system when acting as the origin within a TestScript.
# 	CarePlanActivityStatus: CarePlanActivityStatus - Codes that reflect the current state of a care plan activity within its overall life cycle.
# 	v2.0213: v2 Purge Status - FHIR Value set/code system definition for HL7 v2 table 0213 ( Purge Status)
# 	v3.QueryResponse: v3 Code System QueryResponse -  A code classifying the general nature of the response to a given query. Includes whether or not data was found, or whether an error occurred.
# 	v2.0669: v2 Load Status - FHIR Value set/code system definition for HL7 v2 table 0669 ( Load Status)
# 	ImmunizationEvaluationDoseStatusReasonCodes: Immunization Evaluation Dose Status Reason codes - The value set to instantiate this attribute should be drawn from a terminologically robust code system that consists of or contains concepts to support describing the reason why an administered dose has been assigned a particular status. Often, this reason describes why a dose is considered invalid. This value set is provided as a suggestive example.
# 	v2.0406: v2 Participant Organization Unit Type - FHIR Value set/code system definition for HL7 v2 table 0406 ( Participant Organization Unit Type)
# 	v2.0169: v2 REPORTIN PRIORITY - FHIR Value set/code system definition for HL7 v2 table 0169 ( REPORTIN PRIORITY)
# 	AdverseEventSeverity: AdverseEventSeverity - The severity of the adverse event itself, in direct relation to the subject.
# 	v2.0881: v2 Role Executing Physician - FHIR Value set/code system definition for HL7 v2 table 0881 ( Role Executing Physician)
# 	v2.0761: v2 DRG Procedure Determination Status - FHIR Value set/code system definition for HL7 v2 table 0761 ( DRG Procedure Determination Status)
# 	AdministrativeGender: AdministrativeGender - The gender of a person used for administrative purposes.
# 	ConsentProvisionType: ConsentProvisionType - How a rule statement is applied, such as adding additional consent or removing consent.
# 	IssueType: IssueType - A code that describes the type of issue.
# 	v2.0098: v2 Type of Agreement - FHIR Value set/code system definition for HL7 v2 table 0098 ( Type of Agreement)
# 	v3.Dentition: v3 Code System Dentition - **** MISSING DEFINITIONS ****
# 	StudyType: StudyType - Types of research studies (types of research methods).
# 	v3.Charset: v3 Code System Charset -  Internet Assigned Numbers Authority (IANA) Charset Types
# 	ResourceSecurityCategory: ResourceSecurityCategory - Provides general guidance around the kind of access Control to Read, Search, Create, Update, or Delete a resource.
# 	DetectedIssueSeverity: DetectedIssueSeverity - Indicates the potential degree of impact of the identified issue on the patient.
# 	AssertionOperatorType: AssertionOperatorType - The type of operator to use for assertion.
# 	v2.0917: v2 Bolus Type - FHIR Value set/code system definition for HL7 v2 table 0917 ( Bolus Type)
# 	CapabilityStatementKind: CapabilityStatementKind - How a capability statement is intended to be used.
# 	ImmunizationEvaluationDoseStatusCodes: Immunization Evaluation Dose Status codes - The value set to instantiate this attribute should be drawn from a terminologically robust code system that consists of or contains concepts to support describing the validity of a dose relative to a particular recommended schedule. This value set is provided as a suggestive example.
# 	SurfaceCodes: Surface Codes - This value set includes a smattering of FDI tooth surface codes.
# 	v3.ActRelationshipType: v3 Code System ActRelationshipType -  The source is an excerpt from the target.
# 	v2.0926: v2 Phlebotomy Status - FHIR Value set/code system definition for HL7 v2 table 0926 ( Phlebotomy Status)
# 	v3.ContainerCap: v3 Code System ContainerCap -  The type of cap associated with a container
# 	FinancialTaskCodes: Financial Task Codes - This value set includes Financial Task codes.
# 	v2.0107: v2 DEFERRED RESPONSE TYPE - FHIR Value set/code system definition for HL7 v2 table 0107 ( DEFERRED RESPONSE TYPE)
# 	Australian and New Zealand Standard Classification of Occupations Designation Type: MISSING Title - The Australian and New Zealand Standard Classification of Occupations (ANZSCO) Designation Type code system defines concepts that represent the types of designations used to describe occupation titles in the Australian and New Zealand Standard Classification of Occupations (ANZSCO) code system.
# 	v2.0544: v2 Container Condition - FHIR Value set/code system definition for HL7 v2 table 0544 ( Container Condition)
# 	v3.ProbabilityDistributionType: v3 Code System ProbabilityDistributionType - **** MISSING DEFINITIONS ****
# 	v2.0254: v2 Kind of Quantity - FHIR Value set/code system definition for HL7 v2 table 0254 ( Kind of Quantity)
# 	CommunicationTopic: CommunicationTopic - Codes describing the purpose or content of the communication.
# 	v2.0557: v2 Payee Type - FHIR Value set/code system definition for HL7 v2 table 0557 ( Payee Type)
# 	v2.0365: v2 Equipment state - FHIR Value set/code system definition for HL7 v2 table 0365 ( Equipment state)
# 	v3.PaymentTerms: v3 Code System PaymentTerms -  Describes payment terms for a financial transaction, used in an invoice. This is typically expressed as a responsibility of the acceptor or payor of an invoice.
# 	SlotStatus: SlotStatus - The free/busy status of the slot.
# 	OperationKind: OperationKind - Whether an operation is a normal operation or a query.
# 	v2.0200: v2 Name Type - FHIR Value set/code system definition for HL7 v2 table 0200 ( Name Type)
# 	KnowledgeResourceType: KnowledgeResourceType - A list of all the knowledge resource types defined in this version of the FHIR specification.
# 	v2.0290: v2 MIME base64 encoding Characters - FHIR Value set/code system definition for HL7 v2 table 0290 ( MIME base64 encoding Characters)
# 	v2.0919: v2 Exclusive Test - FHIR Value set/code system definition for HL7 v2 table 0919 ( Exclusive Test)
# 	v3.RelationalOperator: v3 Code System RelationalOperator - **** MISSING DEFINITIONS ****
# 	v2.0006.2.4: v2 table 0006, Version 2.4 - v2 table definition for v2.0006.2.4
# 	v2.0742: v2 DRG Status Financial Calculation - FHIR Value set/code system definition for HL7 v2 table 0742 ( DRG Status Financial Calculation)
# 	v2.0566: v2 Blood Unit Type - FHIR Value set/code system definition for HL7 v2 table 0566 ( Blood Unit Type)
# 	SupplyType: Supply Type - This value sets refers to a Category of supply.
# 	v2.0440: v2 Data types - FHIR Value set/code system definition for HL7 v2 table 0440 ( Data types)
# 	AllergyIntoleranceClinicalStatusCodes: AllergyIntolerance Clinical Status Codes - Preferred value set for AllergyIntolerance Clinical Status.
# 	DeviceMetricOperationalStatus: DeviceMetricOperationalStatus - Describes the operational status of the DeviceMetric.
# 	RequestPriority: RequestPriority - Identifies the level of importance to be assigned to actioning the request.
# 	v3.DeviceAlertLevel: v3 Code System DeviceAlertLevel -  Domain values for the Device.Alert_levelCode
# 	v2.0475: v2 Charge Type Reason - FHIR Value set/code system definition for HL7 v2 table 0475 ( Charge Type Reason)
# 	v3.LanguageAbilityMode: v3 Code System LanguageAbilityMode -  A value representing the method of expression of the language.  Example:
# Expressed spoken, expressed written, expressed signed, received spoken, received written, received signed.  OpenIssue:
# Description copied from Concept Domain of same name.  Must be verified.
# 	v3.DataOperation: v3 Code System DataOperation - **** MISSING DEFINITIONS ****
# 	australian-indigenous-status: Australian Indigenous Status - The Australian Indigenous Status code system defines concepts to support the representation of a person's Indigenous status. That is, whether a person identifies as being of Aboriginal or Torres Strait Islander origin, as represented by a code. The concepts defined in this code system are equivalent to those defined in the METeOR value domains for Person Indigenous status code N for http://meteor.aihw.gov.au/content/index.phtml/itemId/602545, http://meteor.aihw.gov.au/content/index.phtml/itemId/270885, and http://meteor.aihw.gov.au/content/index.phtml/itemId/291036.
# 	DeviceMetricCategory: DeviceMetricCategory - Describes the category of the metric.
# 	v2.0109: v2 REPORT PRIORITY - FHIR Value set/code system definition for HL7 v2 table 0109 ( REPORT PRIORITY)
# 	v2.0338: v2 Practitioner ID number type - FHIR Value set/code system definition for HL7 v2 table 0338 ( Practitioner ID number type)
# 	MatchGrade: MatchGrade - A Master Patient Index (MPI) assessment of whether a candidate patient record is a match or not.
# 	v2.0334: v2 Disabled Person - FHIR Value set/code system definition for HL7 v2 table 0334 ( Disabled Person)
# 	PerformerRoleCodes: Performer Role Codes - This value set includes sample Performer Role codes.
# 	DocumentMode: DocumentMode - Whether the application produces or consumes documents.
# 	v2.0518: v2 Override type - FHIR Value set/code system definition for HL7 v2 table 0518 ( Override type)
# 	v3.TribalEntityUS: v3 Code System TribalEntityUS -  INDIAN ENTITIES RECOGNIZED AND ELIGIBLE TO RECEIVE SERVICES FROM THE UNITED STATES BUREAU OF INDIAN AFFAIRS
# 	v3.ActPriority: v3 Code System ActPriority -  A set of codes (e.g., for routine, emergency), specifying the urgency under which the Act happened, can happen, is happening, is intended to happen, or is requested/demanded to happen.
# 	v2.0501: v2 Consent Non-Disclosure Reason - FHIR Value set/code system definition for HL7 v2 table 0501 ( Consent Non-Disclosure Reason)
# 	TransactionMode: TransactionMode - A code that indicates how transactions are supported.
# 	EvidenceVariableType: EvidenceVariableType - The possible types of variables for exposures or outcomes (E.g. Dichotomous, Continuous, Descriptive).
# 	v2.0175: v2 MASTER FILE IDENTIFIER CODE - FHIR Value set/code system definition for HL7 v2 table 0175 ( MASTER FILE IDENTIFIER CODE)
# 	v2.0242: v2 Primary Observer's Qualification - FHIR Value set/code system definition for HL7 v2 table 0242 ( Primary Observer's Qualification)
# 	FlagStatus: FlagStatus - Indicates whether this flag is active and needs to be displayed to a user, or whether it is no longer needed or was entered in error.
# 	AllergyIntoleranceSubstanceExposureRisk: AllergyIntoleranceSubstanceExposureRisk - The risk of an adverse reaction (allergy or intolerance) for this patient upon exposure to the substance (including pharmaceutical products).
# 	SmartCapabilities: SmartCapabilities - Codes that define what the server is capable of.
# 	v2.0569: v2 Adjustment Action - FHIR Value set/code system definition for HL7 v2 table 0569 ( Adjustment Action)
# 	ExpressionLanguage: ExpressionLanguage - The media type of the expression language.
# 	v2.0208: v2 Query Response Status - FHIR Value set/code system definition for HL7 v2 table 0208 ( Query Response Status)
# 	v2.0719: v2 Access Restriction Reason Code - FHIR Value set/code system definition for HL7 v2 table 0719 ( Access Restriction Reason Code)
# 	AllergyIntoleranceCertainty: AllergyIntoleranceCertainty - Statement about the degree of clinical certainty that a specific substance was the cause of the manifestation in a reaction event.
# 	RequestIntent: RequestIntent - Codes indicating the degree of authority/intentionality associated with a request.
# 	v2.0529: v2 Precision - FHIR Value set/code system definition for HL7 v2 table 0529 ( Precision)
# 	v2.0283: v2 Referral Status - FHIR Value set/code system definition for HL7 v2 table 0283 ( Referral Status)
# 	ConceptMapEquivalence: ConceptMapEquivalence - The degree of equivalence between concepts.
# 	v2.0548: v2 Signatory's Relationship to Subject - FHIR Value set/code system definition for HL7 v2 table 0548 ( Signatory's Relationship to Subject)
# 	v2.0494: v2 Specimen Child Role - FHIR Value set/code system definition for HL7 v2 table 0494 ( Specimen Child Role)
# 	ListOrderCodes: List Order Codes - Base values for the order of the items in a list resource.
# 	BenefitCostApplicability: Benefit cost applicability - Whether the cost applies to in-network or out-of-network providers.
# 	ConformanceExpectation: ConformanceExpectation - Indicates the degree of adherence to a specified behavior or capability expected for a system to be deemed conformant with a specification.
# 	TestReportActionResult: TestReportActionResult - The results of executing an action.
# 	IdentityAssuranceLevel: IdentityAssuranceLevel - The level of confidence that this link represents the same actual person, based on NIST Authentication Levels.
# 	v2.0180: v2 REcord Level Event Code - FHIR Value set/code system definition for HL7 v2 table 0180 ( REcord Level Event Code)
# 	v3.EntityHandling: v3 Code System EntityHandling - **** MISSING DEFINITIONS ****
# 	v2.0510: v2 Blood Product Dispense Status - FHIR Value set/code system definition for HL7 v2 table 0510 ( Blood Product Dispense Status)
# 	v3.IntegrityCheckAlgorithm: v3 Code System IntegrityCheckAlgorithm - **** MISSING DEFINITIONS ****
# 	v2.0130: v2 Visit user code - FHIR Value set/code system definition for HL7 v2 table 0130 ( Visit user code)
# 	Australian Digital Health Agency Person Name Use: MISSING Title - The Australian Digital Health Agency Person Name use code system defines concepts which represent information or specific conditions that may be applied to a name of a person.
# 	v3.TransmissionRelationshipTypeCode: v3 Code System TransmissionRelationshipTypeCode -   Description:
# A code specifying the meaning and purpose of every TransmissionRelationship instance. Each of its values implies specific constraints to what kinds of Transmission objects can be related and in which way.
# 	SpecialArrangements: Special arrangements - This value set defines a set of codes that can be used to indicate the kinds of special arrangements in place for a patients visit.
# 	MedicationDispense Status Reason Codes: Medication dispense  status  reason  codes - MedicationDispense Status Codes
# 	MeasureImprovementNotation: MeasureImprovementNotation - Observation values that indicate what change in a measurement value or score is indicative of an improvement in the measured item or scored issue.
# 	HL7Workgroup: HL7Workgroup - An HL7 administrative unit that owns artifacts in the FHIR specification.
# 	TestReportResult: TestReportResult - The reported execution result.
# 	v2.0122: v2 CHARGE TYPE - FHIR Value set/code system definition for HL7 v2 table 0122 ( CHARGE TYPE)
# 	SNOMED Clinical Terms Australian extension: MISSING Title - SNOMED CT is the most comprehensive and precise clinical health terminology product in the world, owned and distributed around the world by The International Health Terminology Standards Development Organisation (IHTSDO).
# 	ContractResourceScopeCodes: Contract Resource Scope codes - This value set contract specific codes for scope.
# 	v2.0275: v2 Document Storage Status - FHIR Value set/code system definition for HL7 v2 table 0275 ( Document Storage Status)
# 	v2.0504: v2 Sequence Condition Code - FHIR Value set/code system definition for HL7 v2 table 0504 ( Sequence Condition Code)
# 	v2.0066: v2 Employment status - FHIR Value set/code system definition for HL7 v2 table 0066 ( Employment status)
# 	LinkType: LinkType - The type of link between this patient resource and another patient resource.
# 	v2.0490: v2 Specimen Reject Reason - FHIR Value set/code system definition for HL7 v2 table 0490 ( Specimen Reject Reason)
# 	v2.0395: v2 Modify indicator - FHIR Value set/code system definition for HL7 v2 table 0395 ( Modify indicator)
# 	v3.EntityRisk: v3 Code System EntityRisk -  Kinds of risks associated with the handling of the material..
# 	v2.0105: v2 SOURCE OF COMMENT - FHIR Value set/code system definition for HL7 v2 table 0105 ( SOURCE OF COMMENT)
# 	v2.0078: v2 ABNORMAL FLAGS - HL7-defined code system of concepts which specify a categorical assessment of an observation value.
#
#    Notes:
#
#    This is being communicated in v2.x in OBX-8 (Observation Interpretation), in v3 in ObservationInterpretation (CWE) in R1 (Representative Realm) and in FHIR in    Observation.interpretation.
# 	v2.0359: v2 Diagnosis priority - FHIR Value set/code system definition for HL7 v2 table 0359 ( Diagnosis priority)
# 	CareTeamStatus: CareTeamStatus - Indicates the status of the care team.
# 	v2.0616: v2 Address Expiration Reason - FHIR Value set/code system definition for HL7 v2 table 0616 ( Address Expiration Reason)
# 	FHIRSubstanceStatus: FHIRSubstanceStatus - A code to indicate if the substance is actively used.
# 	v2.0220: v2 Living Arrangements - FHIR Value set/code system definition for HL7 v2 table 0220 ( Living Arrangements)
# 	StructureMapTargetListMode: StructureMapTargetListMode - If field is a list, how to manage the production.
# 	QuestionnaireItemType: QuestionnaireItemType - Distinguishes groups from questions and display text and indicates data type for questions.
# 	v2.0230: v2 Procedure Functional Type - FHIR Value set/code system definition for HL7 v2 table 0230 ( Procedure Functional Type)
# 	v2.0232: v2 Insurance Company Contact Reason - FHIR Value set/code system definition for HL7 v2 table 0232 ( Insurance Company Contact Reason)
# 	v2.0315: v2 Living Will - FHIR Value set/code system definition for HL7 v2 table 0315 ( Living Will)
# 	v2.0905: v2 Shipment Status - FHIR Value set/code system definition for HL7 v2 table 0905 ( Shipment Status)
# 	MessageSignificanceCategory: MessageSignificanceCategory - The impact of the content of a message.
# 	Funds Reservation Codes: MISSING Title - This value set includes sample funds reservation type codes.
# 	v2.0776: v2 Item Status - FHIR Value set/code system definition for HL7 v2 table 0776 ( Item Status)
# 	NamingSystemType: NamingSystemType - Identifies the purpose of the naming system.
# 	v2.0061: v2 CHECK DIGIT SCHEME - FHIR Value set/code system definition for HL7 v2 table 0061 ( CHECK DIGIT SCHEME)
# 	v3.AmericanIndianAlaskaNativeLanguages: v3 Code System AmericanIndianAlaskaNativeLanguages -  American Indian and Alaska Native languages currently being used in the United States.
# 	AllergyIntoleranceType: AllergyIntoleranceType - Identification of the underlying physiological mechanism for a Reaction Risk.
# 	ExampleVisionPrescriptionProductCodes: Example Vision Prescription Product Codes - This value set includes a smattering of Prescription Product codes.
# 	ServiceType: Service type - This value set defines an example set of codes of service-types.
# 	v2.0923: v2 Process Interruption - FHIR Value set/code system definition for HL7 v2 table 0923 ( Process Interruption)
# 	v2.0214: v2 Special Program Code - FHIR Value set/code system definition for HL7 v2 table 0214 ( Special Program Code)
# 	v2.0417: v2 Tissue type code - FHIR Value set/code system definition for HL7 v2 table 0417 ( Tissue type code)
# 	NHIN PurposeOfUse: MISSING Title - This value set is suitable for use with the provenance resource. It is derived from, but not compatible with, the HL7 v3 Purpose of use Code system.
# 	v3.Ethnicity: v3 Code System Ethnicity -  In the United States, federal standards for classifying data on ethnicity determine the categories used by federal agencies and exert a strong influence on categorization by state and local agencies and private sector organizations. The federal standards do not conceptually define ethnicity, and they recognize the absence of an anthropological or scientific basis for ethnicity classification.  Instead, the federal standards acknowledge that ethnicity is a social-political construct in which an individual's own identification with a particular ethnicity is preferred to observer identification.  The standards specify two minimum ethnicity categories: Hispanic or Latino, and Not Hispanic or Latino.  The standards define a Hispanic or Latino as a person of "Mexican, Puerto Rican, Cuban, South or Central America, or other Spanish culture or origin, regardless of race." The standards stipulate that ethnicity data need not be limited to the two minimum categories, but any expansion must be collapsible to those categories.  In addition, the standards stipulate that an individual can be Hispanic or Latino or can be Not Hispanic or Latino, but cannot be both.
# 	HTTPVerb: HTTPVerb - HTTP verbs (in the HTTP command line). See [HTTP rfc](https://tools.ietf.org/html/rfc7231) for details.
# 	v2.0267: v2 Days of the Week - FHIR Value set/code system definition for HL7 v2 table 0267 ( Days of the Week)
# 	v3.CommunicationFunctionType: v3 Code System CommunicationFunctionType -  Describes the type of communication function that the associated entity plays in the associated transmission.
# 	v2.0511: v2 BP Observation Status Codes Interpretation - FHIR Value set/code system definition for HL7 v2 table 0511 ( BP Observation Status Codes Interpretation)
# 	StrengthOfRecommendationRating: StrengthOfRecommendationRating - A rating system that describes the strength of the recommendation, such as the GRADE, DynaMed, or HGPS systems.
# ...
# 	library-type: LibraryType
# 	v2-0122: v2.0122
# 	reason-vaccine-administered-1.0.0: Reason Vaccine Administered
# 	v2-0206: v2.0206
# 	v3-GenderStatus: v3.GenderStatus
# 	medication-codes: SNOMEDCTMedicationCodes
# 	related-person-relationship-type-1.0.0: Related Person Relationship Type
# 	immunization-target-disease: ImmunizationTargetDiseaseCodes
# 	v2-0003: v2.0003
# 	specimen-container-type-1: specimen-container-type
# 	v2-0144: v2.0144
# 	v2-0651: v2.0651
# 	location-mode: LocationMode
# 	extensional-case-2: Terminology Services Connectation #1 Extensional case #2
# 	v2-0731: v2.0731
# 	intensional-case-1: Terminology Services Connectation #1 Intensional case #1
# 	v2-0287: v2.0287
# 	communication-not-done-reason: CommunicationNotDoneReason
# 	v3-LocalMarkupIgnore: v3.LocalMarkupIgnore
# 	action-participant-role: ActionParticipantRole
# 	v2-0231: v2.0231
# 	practitioner-role-1.0.0: Practitioner Role
# 	claim-informationcategory: ClaimInformationCategoryCodes
# 	object-lifecycle-events: ObjectLifecycleEvents
# 	v3-ActClass: v3.ActClass
# 	v2-0242: v2.0242
# 	v3-RoleClassPassive: v3.RoleClassPassive
# 	v2-0359: v2.0359
# 	participant-role: ParticipantRoles
# 	ihi-status-1.0.0: Individual Healthcare Identifier Status
# 	v3-Race: v3.Race
# 	v2-0038: v2.0038
# 	medication-request-status-hl7-v3-1: medication-request-status-hl7-v3
# 	ex-onsettype: ExampleOnsetType(Reason)Codes
# 	payment-type: PaymentTypeCodes
# 	detectedissue-category: DetectedIssueCategory
# 	v3-AcknowledgementType: v3.AcknowledgementType
# 	v3-ActClassClinicalDocument: v3.ActClassClinicalDocument
# 	v2-0532: v2.0532
# 	v2-0450: v2.0450
# 	activity-definition-category: ActivityDefinitionCategory
# 	v2-0062: v2.0062
# 	v2-0237: v2.0237
# 	australian-healthcare-entitlement-type-1.0.0: Australian Healthcare Entitlement Type
# 	codesystem-altcode-kind: AlternativeCodeKind
# 	v2-0276: v2.0276
# 	organization-address-use-hl7-v3-1: organization-address-use-hl7-v3
# 	message-reason-encounter: ExampleMessageReasonCodes
# 	special-values: SpecialValues
# 	v2-0251: v2.0251
# 	v2-0102: v2.0102
# 	v2-0749: v2.0749
# 	v2-0366: v2.0366
# 	organ-donation-body-site-1: organ-donation-body-site
# 	v2-0389: v2.0389
# 	timing-abbreviation: TimingAbbreviation
# 	media-type: MediaType
# 	v2-0332: v2.0332
# 	capability-statement-kind: CapabilityStatementKind
# 	immunization-reason: ImmunizationReasonCodes
# 	v2-0243: v2.0243
# 	v2-0618: v2.0618
# 	verificationresult-primary-source-type: primary-source-type
# 	v2-0337: v2.0337
# 	v2-0153: v2.0153
# 	v3-MilitaryRoleType: v3.MilitaryRoleType
# 	medicationdispense-category: MedicationDispense Category Codes
# 	provenance-activity-type: ProvenanceActivityType
# 	designation-use: DesignationUse
# 	v2-0472: v2.0472
# 	v3-SeverityObservation: v3.SeverityObservation
# 	ex-benefitcategory: BenefitCategoryCodes
# 	australian-immunisation-register-vaccine-1.0.0: Australian Immunisation Register Vaccine
# 	v3-ObservationCategory: v3.ObservationCategory
# 	intensional-case-3: Terminology Services Connectation #1 Intensional case #3
# 	patient-contactrelationship: PatientContactRelationship
# 	v2-0033: v2.0033
# 	care-team-status: CareTeamStatus
# 	address-type: AddressType
# 	v3-PatientImportance: v3.PatientImportance
# 	communication-topic: CommunicationTopic
# 	v3-RoleClassAgent: v3.RoleClassAgent
# 	contract-party-role: ContractResourcePartyRoleCodes
# 	audit-event-outcome: AuditEventOutcome
# 	specimen-collection-procedure-1: specimen-collection-procedure
# 	encounter-special-arrangements: SpecialArrangements
# 	reference-handling-policy: ReferenceHandlingPolicy
# 	v2-0316: v2.0316
# 	v2-0793: v2.0793
# 	v2-0201: v2.0201
# 	medication-statement-status: Medication Status Codes
# 	benefit-term: BenefitTermCodes
# 	specimen-processing-procedure: SpecimenProcessingProcedure
# 	v2-0445: v2.0445
# 	v2-0271: v2.0271
# 	v2-0517: v2.0517
# 	product-storage-scale: BiologicallyDerivedProductStorageScale
# 	clinical-findings: SNOMEDCTClinicalFindings
# 	v2-0496: v2.0496
# 	v2-0365: v2.0365
# 	v2-0487: v2.0487
# 	device-kind: FHIRDeviceTypes
# 	v3-SecurityIntegrityObservationValue: v3.SecurityIntegrityObservationValue
# 	v2-0719: v2.0719
# 	v2-0105: v2.0105
# 	iso3166-1-N: Iso3166-1-N
# 	bodysite-laterality: Laterality
# 	v2-0259: v2.0259
# 	allerg-intol-substance-exp-risk: AllergyIntoleranceSubstanceExposureRisk
# 	v3-TransmissionRelationshipTypeCode: v3.TransmissionRelationshipTypeCode
# 	v2-0183: v2.0183
# 	v2-0540: v2.0540
# 	v2-0478: v2.0478
# 	v3-VaccineManufacturer: v3.VaccineManufacturer
# 	v2-0220: v2.0220
# 	coverageeligibilityresponse-ex-auth-support: CoverageEligibilityResponseAuthSupportCodes
# 	insuranceplan-type: InsurancePlanType
# 	v2-0776: v2.0776
# 	examplescenario-actor-type: ExampleScenarioActorType
# 	use-context: Context of Use ValueSet
# 	report-status-codes: TestReportStatus
# 	handling-condition: HandlingConditionSet
# 	research-element-type: ResearchElementType
# 	namingsystem-identifier-type: NamingSystemIdentifierType
# 	referencerange-meaning: ObservationReferenceRangeMeaningCodes
# 	adverse-event-causality-method: AdverseEventCausalityMethod
# 	v3-Compartment: v3.Compartment
# 	v2-0377: v2.0377
# 	subscriber-relationship: SubscriberRelationshipCodes
# 	v2-0205: v2.0205
# 	process-priority: ProcessPriorityCodes
# 	v2-0052: v2.0052
# 	container-material: ContainerMaterials
# 	v2-0430: v2.0430
# 	doc-typecodes: FHIRDocumentTypeCodes
# 	v2-0500: v2.0500
# 	v2-0406: v2.0406
# 	v2-0330: v2.0330
# 	v2-0459: v2.0459
# 	adverse-event-outcome: AdverseEventOutcome
# 	v2-0128: v2.0128
# 	name-v3-representation: NameRepresentationUse
# 	v2-0175: v2.0175
# 	extended-person-name-use-1.0.0: Extended Person Name Use
# 	timezones: IANATimezones
# 	v2-0634: v2.0634
# 	v2-0367: v2.0367
# 	medication-form-1: medication-form
# 	vaccination-target-disease-1.0.0: Vaccination Target Disease
# 	specimen-contained-preference: SpecimenContainedPreference
# 	service-place: ExampleServicePlaceCodes
# 	fm-conditions: FMConditionCodes
# 	condition-cause: ConditionCauseCodes
# 	composition-altcode-kind: AlternativeCodeKind
# 	body-site: SNOMEDCTBodyStructures
# 	food-type: FoodTypeCodes
# 	supplyrequest-reason: SupplyRequestReason
# 	consistency-type: FluidConsistencyTypeCodes
# 	encounter-type: EncounterType
# 	v2-0235: v2.0235
# 	measure-improvement-notation: MeasureImprovementNotation
# 	health-summary-non-clinical-empty-reason-1: health-summary-non-clinical-empty-reason
# 	eligibilityrequest-purpose: EligibilityRequestPurpose
# 	non-clinical-empty-reason-1: non-clinical-empty-reason
# 	v3-CodingRationale: v3.CodingRationale
# 	allelename: HLA
# 	knowledge-resource-types: KnowledgeResourceType
# 	verificationresult-communication-method: verificationresult-communication-method
# 	servicerequest-orderdetail: ServiceRequestOrderDetailsCodes
# 	v3-ProcessingMode: v3.ProcessingMode
# 	v3-ExposureMode: v3.ExposureMode
# 	medicationdispense-status: MedicationDispense Status Codes
# 	exposure-state: ExposureState
# 	service-product: ExampleService/ProductCodes
# 	adverse-event-actuality: AdverseEventActuality
# 	v2-0755: v2.0755
# 	v2-0214: v2.0214
# 	procedure-category: ProcedureCategoryCodes(SNOMEDCT)
# 	measure-data-usage: MeasureDataUsage
# 	anzsco-1.0.0: Australian and New Zealand Standard Classification of Occupations
# 	audit-entity-type: AuditEventEntityType
# 	reference-version-rules: ReferenceVersionRules
# 	immunization-evaluation-status: ImmunizationEvaluationStatusCodes
# 	immunization-recommendation-target-disease: ImmunizationRecommendationTargetDiseaseCodes
# 	v3-xBasicConfidentialityKind: v3.x_BasicConfidentialityKind
# 	questionnaire-questions: QuestionnaireQuestionCodes
# 	v2-0007: v2.0007
# 	icd-10: ICD-10Codes
# 	ihi-record-status-1.0.0: Individual Healthcare Identifier Record Status
# 	v3-NullFlavor: v3.NullFlavor
# 	ex-revenue-center: ExampleRevenueCenterCodes
# 	procedure-followup: ProcedureFollowUpCodes(SNOMEDCT)
# 	v2-0277: v2.0277
# 	intervention: InterventionCodes
# 	v2-0166: v2.0166
# 	v2-0180: v2.0180
# 	v3-TargetAwareness: v3.TargetAwareness
# 	goal-relationship-type: GoalRelationshipType
# 	contract-assetcontext: ContractResourceAssetContextCodes
# 	clinicalimpression-status: ClinicalImpressionStatus
# 	v2-0468: v2.0468
# 	v2-0344: v2.0344
# 	v3-MaritalStatus: v3.MaritalStatus
# 	search-comparator: SearchComparator
# 	date-accuracy-indicator-1: date-accuracy-indicator
# 	device-action: ProcedureDeviceActionCodes
# 	product-category: BiologicallyDerivedProductCategory
# 	v3-RoleClassServiceDeliveryLocation: v3.RoleClassServiceDeliveryLocation
# 	teeth: TeethCodes
# 	coverage-copay-type: CoverageCopayTypeCodes
# 	v2-0116: v2.0116
# 	v3-Confidentiality: v3.Confidentiality
# 	v2-0267: v2.0267
# 	reason-medication-not-given-codes: SNOMEDCTReasonMedicationNotGivenCodes
# 	v2-0227: v2.0227
# 	sibling-relationship-codes: SiblingRelationshipCodes
# 	immunization-evaluation-dose-status: ImmunizationEvaluationDoseStatusCodes
# 	allergyintolerance-code: AllergyIntoleranceSubstance/Product,ConditionAndNegationCodes
# 	v3-ActClassROI: v3.ActClassROI
# 	v3-ContainerSeparator: v3.ContainerSeparator
# 	ucum-bodyweight: BodyWeightUnits
# 	v3-QueryPriority: v3.QueryPriority
# 	task-intent: TaskIntent
# 	contract-expiration-type: ContractResourceExpirationTypeCodes
# 	v2-0625: v2.0625
# 	resource-types: ResourceType
# 	v3-LocalRemoteControlState: v3.LocalRemoteControlState
# 	immunization-function: ImmunizationFunctionCodes
# 	relation-type: CatalogEntryRelationType
# 	risk-estimate-type: RiskEstimateType
# 	contract-term-type: ContractTermTypeCodes
# 	v2-0158: v2.0158
# 	empty-reason-hl7-v3-nullflavor-1: empty-reason-hl7-v3-nullflavor
# 	v2-0279: v2.0279
# 	v2-0907: v2.0907
# 	v2-0566: v2.0566
# 	clinical-condition-1.0.0: Clinical Condition
# 	v3-ActExposureLevelCode: v3.ActExposureLevelCode
# 	v3-ActMoodPredicate: v3.ActMoodPredicate
# 	adverse-event-causality-assess: AdverseEventCausalityAssessment
# 	eligibilityresponse-purpose: EligibilityResponsePurpose
# 	udi-entry-type: UDIEntryType
# 	device-definition-status: FHIRDeviceStatus
# 	episode-of-care-status: EpisodeOfCareStatus
# 	v3-Charset: v3.Charset
# 	med-admin-perform-function: MedicationAdministration Performer Function Codes
# 	v2-0387: v2.0387
# 	v2-0181: v2.0181
# 	v2-0210: v2.0210
# 	medicationdispense-status-reason: MedicationDispense Status Reason Codes
# 	laterality-1.0.0: Laterality
# 	code-search-support: CodeSearchSupport
# 	v3-ServiceDeliveryLocationRoleType: v3.ServiceDeliveryLocationRoleType
# 	v2-0135: v2.0135
# 	link-type: LinkType
# 	nutrient-code: NutrientModifierCodes
# 	c80-practice-codes: PracticeSettingCodeValueSet
# 	v2-0322: v2.0322
# 	v2-0092: v2.0092
# 	endpoint-payload-type: EndpointPayloadType
# 	v3-ActRelationshipSplit: v3.ActRelationshipSplit
# 	cdshooks-indicator: Indicator
# 	benefit-network: NetworkTypeCodes
# 	benefit-unit: UnitTypeCodes
# 	v2-0818: v2.0818
# 	subscription-tag: SubscriptionTag
# 	v2-0125: v2.0125
# 	v2-0098: v2.0098
# 	v2-0402: v2.0402
# 	encounter-act-status-hl7-v3-1: encounter-act-status-hl7-v3
# 	v3-AdministrativeGender: v3.AdministrativeGender
# 	medicationrequest-category: medicationRequest Category Codes
# 	map-group-type-mode: StructureMapGroupTypeMode
# 	codesystem-hierarchy-meaning: CodeSystemHierarchyMeaning
# 	v2-0427: v2.0427
# 	condition-outcome: ConditionOutcomeCodes
# 	v3-ActClassSupply: v3.ActClassSupply
# 	request-intent: RequestIntent
# 	contract-actionstatus: ContractResourceActionStatusCodes
# 	medication-reason-not-taken-1: medication-reason-not-taken
# 	v2-0455: v2.0455
# 	v2-0273: v2.0273
# 	sequence-referenceSeq: ENSEMBL
# 	v2-0436: v2.0436
# 	clinical-finding-1.0.0: Clinical Finding
# 	group-measure: GroupMeasure
# 	v2-0174: v2.0174
# 	v3-ResponseModality: v3.ResponseModality
# 	diagnosis-role: DiagnosisRole
# 	linkage-type: LinkageType
# 	v3-RoleStatus: v3.RoleStatus
# 	adverse-event-type: SNOMEDCTClinicalFindings
# 	catalogType: CatalogType
# 	condition-stage-type: ConditionStageType
# 	quality-type: qualityType
# 	action-precheck-behavior: ActionPrecheckBehavior
# 	v3-ParticipationPhysicalPerformer: v3.ParticipationPhysicalPerformer
# 	v3-ActConsentType: v3.ActConsentType
# 	v2-0012: v2.0012
# 	participation-role-type: ParticipationRoleType
# 	medicine-substitution-reason-1: medicine-substitution-reason
# 	v2-0393: v2.0393
# 	task-code: TaskCode
# 	v2-0255: v2.0255
# 	flag-status: FlagStatus
# 	contract-content-derivative: ContractContentDerivationCodes
# 	v2-0004: v2.0004
# 	v3-ProvenanceEventCurrentState: v3.ProvenanceEventCurrentState
# 	v3-ActMoodIntent: v3.ActMoodIntent
# 	vision-eye-codes: VisionEyes
# 	v3-EntityNamePartTypeR2: v3.EntityNamePartTypeR2
# 	immunization-recommendation-status: ImmunizationRecommendationStatusCodes
# 	clinical-finding-1: clinical-finding
# 	care-plan-activity-outcome: CarePlanActivityOutcome
# 	v3-hl7PublishingSubSection: v3.hl7PublishingSubSection
# 	effect-estimate-type: EffectEstimateType
# 	v3-RoleClassAssociative: v3.RoleClassAssociative
# 	intensional-case-2: Terminology Services Connectation #1 Intensional case #2
# 	program: Program
# 	map-target-list-mode: StructureMapTargetListMode
# 	ex-program-code: ExampleProgramReasonCodes
# 	v2-0061: v2.0061
# 	questionnaireresponse-mode: QuestionnaireResponseMode
# 	v2-0265: v2.0265
# 	observation-codes: LOINCCodes
# 	history-status: FamilyHistoryStatus
# 	v2-0131: v2.0131
# 	ihi-record-status-1: individual-healthcare-identifier-record-status
# 	restful-security-service: RestfulSecurityService
# 	v3-GeneralPurposeOfUse: v3.GeneralPurposeOfUse
# 	v2-0432: v2.0432
# 	v2-0272: v2.0272
# 	approach-site-codes: SNOMEDCTAnatomicalStructureForAdministrationSiteCodes
# 	questionnaire-answers-status: QuestionnaireResponseStatus
# 	contact-point-use: ContactPointUse
# 	age-units: CommonUCUMCodesForAge
# 	messageheader-response-request: messageheader-response-request
# 	v2-0001: v2.0001
# 	condition-category: ConditionCategoryCodes
# 	v2-0263: v2.0263
# 	synthesis-type: SynthesisType
# 	devicemetric-type: DeviceMetricAndComponentTypes
# 	v2-0544: v2.0544
# 	v2-0442: v2.0442
# 	coverage-selfpay: CoverageSelfPayCodes
# 	service-category: ServiceCategory
# 	vision-product: ExampleVisionPrescriptionProductCodes
# 	v2-0169: v2.0169
# 	transaction-mode: TransactionMode
# 	australian-mainland-states: Australian mainland states
# 	procedure-not-performed-reason: ProcedureNotPerformedReason(SNOMED-CT)
# 	resource-type-link: PayeeResourceType
# 	v3-DocumentCompletion: v3.DocumentCompletion
# 	health-summary-empty-reason-hl7-v3-nullflavor-1: health-summary-empty-reason-hl7-v3-nullflavor
# 	measure-type: MeasureType
# 	risk-probability: RiskProbability
# 	v3-EntityDeterminerDetermined: v3.EntityDeterminerDetermined
# 	document-mode: DocumentMode
# 	contract-assettype: ContractResourceAssetTypeCodes
# 	encounter-location-status: EncounterLocationStatus
# 	v2-0922: v2.0922
# 	v2-0894: v2.0894
# 	action-cardinality-behavior: ActionCardinalityBehavior
# 	related-person-relationship-type-1: related-person-relationship-type
# 	testscript-profile-destination-types: TestScriptProfileDestinationType
# 	formatcodes: DocumentReferenceFormatCodeSet
# 	v2-0147: v2.0147
# 	v2-0423: v2.0423
# 	v2-0325: v2.0325
# 	v3-DataOperation: v3.DataOperation
# 	financial-taskcode: FinancialTaskCodes
# 	immunisation-route-of-administration-1.0.0: Immunisation Route of Administration
# 	device-nametype: DeviceNameType
# 	extension-context-type: ExtensionContextType
# 	v3-Dentition: v3.Dentition
# 	v2-0489: v2.0489
# 	v2-0570: v2.0570
# 	specimen-container-type-1.0.0: Specimen Container Type
# 	questionnaire-answers: QuestionnaireAnswerCodes
# 	reason-for-admission-1: reason-for-admission
# 	flag-code: FlagCode
# 	v2-0490: v2.0490
# 	group-type: GroupType
# 	australian-dhs-modifications-pbs-mbs-dva-item-1.0.0: Australian Department of Human Services Modifications of Pharmaceutical Benefits Scheme Schedule Item, Medicare Benefits Schedule Item and Department of Veterans' Affairs Fee Schedule Item
# 	v2-0160: v2.0160
# 	v2-0734: v2.0734
# 	contract-subtype: ContractSubtypeCodes
# 	medicationrequest-status: medicationrequest Status
# 	contract-decision-mode: ContractResourceDecisionModeCodes
# 	v3-ActRelationshipPertains: v3.ActRelationshipPertains
# 	episodeofcare-type: EpisodeOfCareType
# 	detectedissue-mitigation-action: DetectedIssueMitigationAction
# 	conformance-expectation: ConformanceExpectation
# 	v2-0170: v2.0170
# 	v2-0834: v2.0834
# 	contract-signer-type: ContractSignerTypeCodes
# 	v2-0108: v2.0108
# 	v2-0508: v2.0508
# 	route-of-administration-1: route-of-administration
# 	99894e74-cf49-47d5-9968-f4541afe04b4: USCoreMedicationCodes
# 	probability-distribution-type: ProbabilityDistributionType
